# %%
from k_means import *
import numpy
from matplotlib import pyplot

dots = [(1,4), (2,2), (2,3), (3,2), (8,3), (2,5), (3,4), (7,2), (7,4),
        (6,3), (5,2), (5,6), (6,6), (6,7), (5,8), (4,8)]

# %%
COORDINATE_MAX = 11

for dot in dots:
    pyplot.scatter(dot[0], dot[1], c="b")
    
pyplot.show()

# %%
color_codes = ["b", "r", "y", "c", "m", "y", "k", "w"]

k = 4
NUM_DOTS = 40
random_dots = list(zip(numpy.random.randn(NUM_DOTS), 
                       numpy.random.randn(NUM_DOTS)))

group_of_dots = k_means(random_dots, k)

for i in range(k):
    for dot in group_of_dots[i]:
        pyplot.scatter(dot[0], dot[1], c=color_codes[i], s=70)

pyplot.show()
# Out:
# [(0.55064395171869518, -1.9313027888564445), (1.2281374606691071, -0.69528692788478985), (0.37805855773408092, 0.38074855433579025), (0.59746841868880707, -0.33566780406451635)]
# 1
# [(0.11642340491408446, -1.6533362563550138), (0.99474697908476584, -0.73876665475263648), (-0.77409616967226957, 0.37198912430526215), (-0.042548365659303727, -0.57135017171835822)]
# 2
# [(0.13405234458054713, -1.9209244790532793), (0.85113768684268931, -0.61421712148106078), (-1.0811171754386038, 0.39398579029439379), (-0.2599229513352001, -0.45030286126677044)]
# 3
# [(0.43434406152155747, -1.8277378773450259), (0.79132727801164371, -0.51388515162888493), (-1.0875821333748485, 0.45270509814905813), (-0.369725349137069, -0.43415205697939707)]
# 4
# [(0.43434406152155747, -1.8277378773450259), (0.75375739435004696, -0.43255481472300539), (-1.1160530535775723, 0.49167238451620332), (-0.45399602055810906, -0.46758422459167559)]
# 5
# [(0.43434406152155747, -1.8277378773450259), (0.66079975338964048, -0.37064740364831644), (-1.1333565589565202, 0.54194048703524944), (-0.59245205937503553, -0.51081887332742326)]
# 6
# [(0.43434406152155747, -1.8277378773450259), (0.58229151841472981, -0.34149359702344195), (-1.1492063946562789, 0.59927049830484225), (-0.74658264190138379, -0.53768440081234847)]
# 7
